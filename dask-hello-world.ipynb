# %%
import dask.dataframe as dd
from dask.distributed import Client

# %%
# Create a dask client if you want to use the dashboard
#client = Client()
#client.restart()
# Out:
# 2022-09-14 14:50:53,416 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-l519fyg4', purging
# 2022-09-14 14:50:53,417 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-gocfqyb5', purging
# 2022-09-14 14:50:53,417 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-jke6709y', purging
# 2022-09-14 14:50:53,417 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-ft7yqoh8', purging
# 2022-09-14 14:50:53,417 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-nmyvo72t', purging
# 2022-09-14 14:50:53,417 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-8m_2aivo', purging
# 2022-09-14 14:50:53,418 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-nrn79ng5', purging
# 2022-09-14 14:50:53,418 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-cnjedj5s', purging
# 2022-09-14 14:50:53,896 - distributed.nanny - WARNING - Restarting worker
# 2022-09-14 14:50:53,900 - distributed.nanny - WARNING - Restarting worker
# 2022-09-14 14:50:53,902 - distributed.nanny - WARNING - Restarting worker
# 2022-09-14 14:50:53,911 - distributed.nanny - WARNING - Restarting worker
# <Client: 'tcp://127.0.0.1:40921' processes=4 threads=16, memory=31.36 GiB>

# %%
ddf = dd.read_parquet(
    "s3://dask-data/nyc-taxi/nyc-2015.parquet/part.*.parquet",
    columns=["passenger_count", "tip_amount"],
    storage_options={"anon": True},
)

# %%
result = ddf.groupby("passenger_count").tip_amount.mean().compute()
result
# Out:
# passenger_count
# 0    1.590343
# 1    1.752130
# 2    1.705595
# 3    1.579748
# 4    1.459269
# 5    1.728534
# 6    1.680769
# 7    3.863473
# 8    5.060718
# 9    5.075917
# Name: tip_amount, dtype: float64
